# %%
import sys
sys.path.insert(0, '/private/groups/brookslab/gabai/tools/seqUtils/src/')
import time
import numpy as np
from seqUtil import *
from bamUtil import *
from nanoUtil import *
from nntUtil import *
from modPredict import *
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Device type:  cpu

# %%
nuc_regions = {
    'PHO5': 'chrII:429000-435000',
    'CLN2': 'chrXVI:66000-67550',
    'HMR': 'chrIII:290000-299000'
}

models = {
    'resnet1D':resnet1D
}
myregion = nuc_regions['PHO5']
mymodel = models['resnet1D']
myweights =  '/private/groups/brookslab/gabai/tools/seqUtils/src/nanopore_classification/best_models/addseq_resnet1d.pt'

reg = myregion.split(':')
chrom, pStart, pEnd = reg[0], int(reg[1].split('-')[0]), int(reg[1].split('-')[1])

# %%
genome = '/private/groups/brookslab/gabai/projects/Add-seq/data/ref/sacCer3.fa'
chrom_bam = '/private/groups/brookslab/gabai/projects/Add-seq/data/chrom/mapping/all_read.bam'
pos_bam = '/private/groups/brookslab/gabai/projects/Add-seq/data/ctrl/mapping/unique.500.pass.sorted.bam'
neg_bam = '/private/groups/brookslab/gabai/projects/Add-seq/data/ctrl/mapping/unique.0.pass.sorted.bam'
chrom_evt = '/private/groups/brookslab/gabai/projects/Add-seq/data/chrom/eventalign/all_read.eventalign.txt'
pos_evt = '/private/groups/brookslab/gabai/projects/Add-seq/data/ctrl/eventalign/unique.500.eventalign.tsv'
neg_evt = '/private/groups/brookslab/gabai/projects/Add-seq/data/ctrl/eventalign/unique.0.eventalign.tsv'

# %%
def parseEventAlign(eventAlign = '', outfile = '', readname = '', chr_region = '', print_sequence = False, n_rname = 0, header = True):
    '''
    This function reads nanopolish eventalign file, aggregates signals and the number of 
    signals correspinding to one base movement for read in readname list.
    
    input:
        eventAlign: nanopolish eventalign output file.
        readname: A list containing readnames.
        chr_region: chromosome number that region of interest falls in.
    optional:
        print_sequence: if True, kmer sequence will be included in outfile.
        n_rname: number of readnames can be skipped in the readname list (default: 0).
                 Searching all the readnames from the eventalign file takes longer time.
    output: 
        outfile: siganlAlign.tsv with format: readname\tchrom\teventStart(reference)\tsigList\tsigLenLsit

    E.g.    read1  ACGTGGCTGA
            events ACGTG
                    CGTGG
                     GTGGC
                      TGGCT
                       GGCTG
                        GCTGA
            sigLen  23
                     45
                      61
                       78
                        101
    '''
    readname = set(readname)
    if outfile:
        outf = open(outfile, 'w')
    tag = ''
    read = ''
    sequence = ''
    c = 0
    readok = False
    
    with open(eventAlign, 'r') as inFile:
        if header:
            header = inFile.readline()
        for line in inFile:
            line = line.strip().split('\t')
            thisread = line[3]
            thischrom = line[0]
            c+=1
            if c%10000000 == 0:
                print(c/1000000, ' M lines have passed.')

            if thischrom != chr_region:
                continue
#             print(line[1], line[2])
            # all line passed the chromosome and readname check should start here
            if thisread != read:
                if sequence:
                    # Set variables back to initial state
                    if print_sequence:
                        out = "{}\t{}\t{}\t{}\t{}\t{}\n".format(read, chrom, eventStart, sequence, ','.join(str(i) for i in sigList), ','.join(str(i) for i in sigLenList))
                    else:
                        out = "{}\t{}\t{}\t{}\t{}\n".format(read, chrom, eventStart, ','.join(str(i) for i in sigList), ','.join(str(i) for i in sigLenList))
                    if outfile:
                        outf.write(out)
                    if len(readname) <= n_rname:
                        sequence = ''
                        break
                    read = ''
                    sequence = ''
                    sigList = []
                    sigLenList = []
                
                if thisread in readname:
                    readname.remove(thisread)
                    print(len(readname), ' reads left in readname list')
                else:
                    continue

                # start new read here
                read = thisread
                chrom = thischrom
                eventStart = line[1]
                start = line[1]
                kmer = line[2]

                # signals are stored in column 13/15 and are separated my comma
                sigList = [float(i) for i in line[-1].split(',')]
                sigLen = len(sigList)
                sigLenList = [sigLen]
                sequence = kmer
            # next kmer within the same read
            else:
                signals = [float(i) for i in line[-1].split(',')]
                # or signalList += signals
                sigList.extend(signals)
                # signalLength records the number of signals for one base movement
                sigLen += len(signals)

                # If different kmer
                if (line[1], line[2]) != (start, kmer):
                    deletion = int(line[1]) - int(start) - 1
                    # id there is a deletion in eventalign file
                    if deletion > 0:
                        sequence += deletion*'D'
                        for i in range(deletion):
                            sigLenList.append(sigLenList[-1])
                    start = line[1]
                    kmer = line[2]
                    sequence += kmer[-1]
                    sigLenList.append(sigLen)
                # If same kmer
                else:
                    # Update the number of signals matched to previous kmer
                    sigLenList[-1]=sigLen
        if sequence:
            if print_sequence:
                out = "{}\t{}\t{}\t{}\t{}\t{}\n".format(read, chrom, eventStart, sequence, ','.join(str(i) for i in sigList), ','.join(str(i) for i in sigLenList))
            else:
                out = "{}\t{}\t{}\t{}\t{}\n".format(read, chrom, eventStart, ','.join(str(i) for i in sigList), ','.join(str(i) for i in sigLenList))
            if outfile:
                outf.write(out)
    outf.close()

# %%
inFile ='/private/groups/brookslab/gabai/projects/Add-seq/data/chrom/eventalign/dcc687c3-af48-4c9c-9a6b-06df1112187d.eventalign.txt'
outFile = '/private/groups/brookslab/gabai/projects/Add-seq/data/chrom/eventalign/dcc687c3-af48-4c9c-9a6b-06df1112187d.sigAlign.txt'
parseEventAlign(eventAlign = inFile, outfile = outFile, 
                readname = ['dcc687c3-af48-4c9c-9a6b-06df1112187d'], 
                chr_region = 'chrII', header = False)
# Out:
# 0  reads left in readname list

# %%
sigAlign_output = '/private/groups/brookslab/gabai/projects/Add-seq/data/ctrl/eventalign/231012_PHO5_chrom_chrII:429000-435000siganlAlign.tsv'

# %%
alignment = getAlignedReads(sam = chrom_bam, region = myregion, genome=genome, print_name=False)

# %%
def assign_scores(readID, sigList, siglenList, sigLenList_init, modbase, alignemnt, 
                  weights, model, device, 
                  tune = False, method = 'median', kmerWindow=80, signalWindow=400):
    
    refSeq = alignemnt['ref']
    # Position of As, relative to the reference
    modPositions = basePos(refSeq, base = modbase)
    modScores = {i:[] for i in modPositions}
    
    for pos in range(len(refSeq)):
        if pos % 500 ==0:
            print('Predicting at position:', pos)
        
        # 1. Fetch sequences with kmer window size, this step is optional
        # seq = refSeq[pos:pos+kmerWindow]
        # 2. Fetch signals with signal window size 
        print('sigLenList_init:', sigLenList_init)
        pos_sigLenList_start = int(sigLenList_init)+pos
        pos_sigLenList_end = pos_sigLenList_start+1
        if pos_sigLenList_start<0: 
            start=0
        else:
            start = int(siglenList[pos_sigLenList_start])
#         if len(sigList)-start<400:
#             print('Reached the end of the signal.')
#             break
        end = int(siglenList[pos_sigLenList_end])
        # If no signals aligned to this position. E.g. chrII 429016 is missed is eventalign output.
        if start == end:
            print('No signal captured at position: ', pos)
            continue
        signals = [float(s) for s in sigList[start:end+signalWindow]]
        # 3. Get predicted probability score from machine learning model
        prob = nntPredict(signals,device = device, model = model, weights_path = weights)
        print('sequence length: ', len(seq), ', signal length: ', len(signals), ', prob: ', prob)
        if len(signals) == 400:
            print(start, end)
            break
        # 4. Assign predicted scores to each modPosition
        # modifiable positions [1,3,4,5,7,10,15,16,21,40]
        # kmer position is 2: [2:2+22]
        # modbase_left = 0
        # modbase_right = 9
        # modifiable position within kmer window [3,4,5,7,10,15,16,21]
        modbase_left = bisect.bisect_left(modPositions, pos)
        modbase_right = bisect.bisect_right(modPositions, pos+kmerWindow)
        modbase_count = modbase_right - modbase_left
        
        for p in range(modbase_left, modbase_right):
            modPosition = modPositions[p]
            # 4.1 Tune signals based on position of A and A content:
            if tune:
                strand = alignemnt[readID][1]
                prob = model_scores(prob, modPosition, pos, modbase_count, strand)
            modScores[modPosition].append(prob)
    
    for mod in modScores:
        modScores[mod] = aggregate_scors(modScores[mod], method = method)
    return modScores

# %%
sigAlign_output = '/private/groups/brookslab/gabai/projects/Add-seq/data/chrom/eventalign/dcc687c3-af48-4c9c-9a6b-06df1112187d.sigAlign.txt'

# %%
thisread = {}
for readID, eventStart, sigList, siglenList in parseSigAlign(sigAlign=sigAlign_output):
    start_time = time.time()
    sigLenList_init = pStart-eventStart-1
    thisread[readID] = [sigList, siglenList, sigLenList_init]

# %%
read = 'dcc687c3-af48-4c9c-9a6b-06df1112187d'
thismodscores = assign_scores(readID=read, sigList=thisread[read][0], siglenList=thisread[read][1], 
                              sigLenList_init=thisread[read][2], 
                              modbase='A', alignemnt=alignment, weights=myweights, model=mymodel, device='cpu', 
                              tune = False, method = 'median', kmerWindow=80, signalWindow=400)
# Out:
# Predicting at position: 0
# sigLenList_init: 22929
# sequence length:  80 , signal length:  403 , prob:  0.3807646731535594
# sigLenList_init: 22929
# sequence length:  80 , signal length:  407 , prob:  0.39741207872118267
# sigLenList_init: 22929
# sequence length:  80 , signal length:  412 , prob:  0.3993050654729207
# sigLenList_init: 22929
# sequence length:  80 , signal length:  407 , prob:  0.39528991494859966
# sigLenList_init: 22929
# sequence length:  80 , signal length:  403 , prob:  0.39726178844769794
# sigLenList_init: 22929
# sequence length:  80 , signal length:  411 , prob:  0.4116072492165999
# sigLenList_init: 22929
# sequence length:  80 , signal length:  407 , prob:  0.4167107045650482
# sigLenList_init: 22929
# sequence length:  80 , signal length:  404 , prob:  0.411438912153244
# sigLenList_init: 22929
# sequence length:  80 , signal length:  404 , prob:  0.40501508116722107
# sigLenList_init: 22929
# sequence length:  80 , signal length:  412 , prob:  0.39113952467838925
# sigLenList_init: 22929
# sequence length:  80 , signal length:  405 , prob:  0.4051560819149017
# sigLenList_init: 22929
# sequence length:  80 , signal length:  404 , prob:  0.4084548130631447
# sigLenList_init: 22929
# sequence length:  80 , signal length:  403 , prob:  0.390877644220988
# sigLenList_init: 22929
# sequence length:  80 , signal length:  413 , prob:  0.40281552305588353
# sigLenList_init: 22929
# sequence length:  80 , signal length:  407 , prob:  0.39426485555512564
# sigLenList_init: 22929
# sequence length:  80 , signal length:  410 , prob:  0.41265260279178617
# sigLenList_init: 22929
# No signal captured at position:  16
# sigLenList_init: 22929
# sequence length:  80 , signal length:  404 , prob:  0.4305475950241089
# sigLenList_init: 22929
# sequence length:  80 , signal length:  403 , prob:  0.4256460666656494
# sigLenList_init: 22929
# sequence length:  80 , signal length:  405 , prob:  0.4754243493080139
# sigLenList_init: 22929
# sequence length:  80 , signal length:  403 , prob:  0.469131996234258
# sigLenList_init: 22929
# sequence length:  80 , signal length:  409 , prob:  0.4459682106971741
# sigLenList_init: 22929
# sequence length:  80 , signal length:  410 , prob:  0.45805014073848727
# sigLenList_init: 22929
# sequence length:  80 , signal length:  409 , prob:  0.4420844382709927
# sigLenList_init: 22929
# sequence length:  80 , signal length:  422 , prob:  0.4253224500200965
# sigLenList_init: 22929
# sequence length:  80 , signal length:  412 , prob:  0.424520122508208
# sigLenList_init: 22929
# sequence length:  80 , signal length:  415 , prob:  0.4014190594355265
# sigLenList_init: 22929
# sequence length:  80 , signal length:  403 , prob:  0.42365797360738117
# sigLenList_init: 22929
# sequence length:  80 , signal length:  407 , prob:  0.421751537493297
# sigLenList_init: 22929
# sequence length:  80 , signal length:  403 , prob:  0.4465443293253581
# sigLenList_init: 22929
# sequence length:  80 , signal length:  405 , prob:  0.4436818063259125
# sigLenList_init: 22929
# sequence length:  80 , signal length:  403 , prob:  0.406338095664978
# sigLenList_init: 22929
# sequence length:  80 , signal length:  405 , prob:  0.4302962005138397
# sigLenList_init: 22929
# sequence length:  80 , signal length:  406 , prob:  0.4519919405380885
# sigLenList_init: 22929
# sequence length:  80 , signal length:  403 , prob:  0.407419890165329
# sigLenList_init: 22929
# sequence length:  80 , signal length:  412 , prob:  0.43820339689652127
# sigLenList_init: 22929
# sequence length:  80 , signal length:  408 , prob:  0.4266483895480633
# sigLenList_init: 22929
# sequence length:  80 , signal length:  403 , prob:  0.4254097143809001
# sigLenList_init: 22929
# sequence length:  80 , signal length:  408 , prob:  0.41439760476350784
# sigLenList_init: 22929
# sequence length:  80 , signal length:  406 , prob:  0.4300682644049327
# sigLenList_init: 22929
# sequence length:  80 , signal length:  403 , prob:  0.4495367705821991
# sigLenList_init: 22929
# sequence length:  80 , signal length:  403 , prob:  0.4197331468264262
# sigLenList_init: 22929
# sequence length:  80 , signal length:  407 , prob:  0.42755432639803204
# sigLenList_init: 22929
# sequence length:  80 , signal length:  406 , prob:  0.45764516294002533
# sigLenList_init: 22929
# sequence length:  80 , signal length:  416 , prob:  0.4396546222269535
# sigLenList_init: 22929
# sequence length:  80 , signal length:  408 , prob:  0.4376126602292061
# sigLenList_init: 22929
# sequence length:  80 , signal length:  406 , prob:  0.4541415770848592
# sigLenList_init: 22929
# sequence length:  80 , signal length:  411 , prob:  0.4234170507300984
# sigLenList_init: 22929
# sequence length:  80 , signal length:  407 , prob:  0.44960454532078337
# sigLenList_init: 22929
# sequence length:  80 , signal length:  412 , prob:  0.4527893314758937
# sigLenList_init: 22929
# sequence length:  80 , signal length:  404 , prob:  0.4372398927807808
# sigLenList_init: 22929
# sequence length:  80 , signal length:  406 , prob:  0.45755767822265625
# sigLenList_init: 22929
# sequence length:  80 , signal length:  415 , prob:  0.45111953020095824
# sigLenList_init: 22929
# sequence length:  80 , signal length:  409 , prob:  0.45629580484496224
# sigLenList_init: 22929
# sequence length:  80 , signal length:  407 , prob:  0.466641902923584
# sigLenList_init: 22929
# sequence length:  80 , signal length:  404 , prob:  0.45759160071611404
# sigLenList_init: 22929
# sequence length:  80 , signal length:  405 , prob:  0.45263181924819945
# sigLenList_init: 22929
# sequence length:  80 , signal length:  405 , prob:  0.4493071258068085
# sigLenList_init: 22929
# sequence length:  80 , signal length:  407 , prob:  0.42838054469653536
# sigLenList_init: 22929
# sequence length:  80 , signal length:  406 , prob:  0.4343247214953105
# sigLenList_init: 22929
# sequence length:  80 , signal length:  414 , prob:  0.4386010489293507
# sigLenList_init: 22929
# sequence length:  80 , signal length:  417 , prob:  0.4357561924878289
# sigLenList_init: 22929
# sequence length:  80 , signal length:  410 , prob:  0.46114557683467866
# sigLenList_init: 22929
# sequence length:  80 , signal length:  415 , prob:  0.43934606909751894
# sigLenList_init: 22929
# sequence length:  80 , signal length:  404 , prob:  0.42106159776449203
# sigLenList_init: 22929
# sequence length:  80 , signal length:  410 , prob:  0.4507093906402588
# sigLenList_init: 22929
# sequence length:  80 , signal length:  421 , prob:  0.431903878847758
# sigLenList_init: 22929
# sequence length:  80 , signal length:  419 , prob:  0.4342611494817232
# sigLenList_init: 22929
# sequence length:  80 , signal length:  410 , prob:  0.44472562670707705
# sigLenList_init: 22929
# sequence length:  80 , signal length:  409 , prob:  0.42485901713371277
# sigLenList_init: 22929
# sequence length:  80 , signal length:  409 , prob:  0.418234732415941
# sigLenList_init: 22929
# sequence length:  80 , signal length:  405 , prob:  0.4441919684410095
# sigLenList_init: 22929
# sequence length:  80 , signal length:  406 , prob:  0.41317740082740784
# sigLenList_init: 22929
# sequence length:  80 , signal length:  411 , prob:  0.42698077992959454
# sigLenList_init: 22929
# sequence length:  80 , signal length:  410 , prob:  0.4291675925254822
# sigLenList_init: 22929
# No signal captured at position:  75
# sigLenList_init: 22929
# sequence length:  80 , signal length:  406 , prob:  0.4540058026711146
# sigLenList_init: 22929
# sequence length:  80 , signal length:  403 , prob:  0.43350760142008465
# sigLenList_init: 22929
# sequence length:  80 , signal length:  409 , prob:  0.44648172126875985
# sigLenList_init: 22929
# sequence length:  80 , signal length:  425 , prob:  0.4535544288158417
# sigLenList_init: 22929
# sequence length:  80 , signal length:  409 , prob:  0.4839190873834822
# sigLenList_init: 22929
# sequence length:  80 , signal length:  410 , prob:  0.4620839387178421
# sigLenList_init: 22929
# sequence length:  80 , signal length:  406 , prob:  0.4696510136127472
# sigLenList_init: 22929
# sequence length:  80 , signal length:  412 , prob:  0.495531901717186
# sigLenList_init: 22929
# sequence length:  80 , signal length:  408 , prob:  0.4886886812746525
# sigLenList_init: 22929
# sequence length:  80 , signal length:  404 , prob:  0.4715614840388298
# sigLenList_init: 22929
# sequence length:  80 , signal length:  407 , prob:  0.47525327120508465
# sigLenList_init: 22929
# sequence length:  80 , signal length:  408 , prob:  0.4645998179912567
# sigLenList_init: 22929
# sequence length:  80 , signal length:  413 , prob:  0.4689975426747249
# sigLenList_init: 22929
# sequence length:  80 , signal length:  405 , prob:  0.4645633339881897
# sigLenList_init: 22929
# sequence length:  80 , signal length:  405 , prob:  0.44993193745613097
# sigLenList_init: 22929
# sequence length:  80 , signal length:  416 , prob:  0.46073607355356216
# sigLenList_init: 22929
# sequence length:  80 , signal length:  408 , prob:  0.46128929033875465
# sigLenList_init: 22929
# sequence length:  80 , signal length:  408 , prob:  0.4689956270158291
# sigLenList_init: 22929
# sequence length:  80 , signal length:  415 , prob:  0.4548739989598592
# sigLenList_init: 22929
# sequence length:  80 , signal length:  412 , prob:  0.4443569133679072
# sigLenList_init: 22929
# sequence length:  80 , signal length:  410 , prob:  0.4703119874000549
# sigLenList_init: 22929
# sequence length:  80 , signal length:  406 , prob:  0.4757387389739354
# sigLenList_init: 22929
# sequence length:  80 , signal length:  403 , prob:  0.48858105142911273
# sigLenList_init: 22929
# sequence length:  80 , signal length:  416 , prob:  0.470766669139266
# sigLenList_init: 22929
# sequence length:  80 , signal length:  416 , prob:  0.45723116770386696
# sigLenList_init: 22929
# sequence length:  80 , signal length:  406 , prob:  0.472241352001826
# sigLenList_init: 22929
# sequence length:  80 , signal length:  407 , prob:  0.4061311994280134
# sigLenList_init: 22929
# sequence length:  80 , signal length:  404 , prob:  0.44138067960739136
# sigLenList_init: 22929
# sequence length:  80 , signal length:  407 , prob:  0.42877474427223206
# sigLenList_init: 22929
# sequence length:  80 , signal length:  408 , prob:  0.40816186368465424
# sigLenList_init: 22929
# sequence length:  80 , signal length:  403 , prob:  0.43877771496772766
# sigLenList_init: 22929
# sequence length:  80 , signal length:  420 , prob:  0.4423427954316139
# sigLenList_init: 22929
# sequence length:  80 , signal length:  405 , prob:  0.434764164686203
# sigLenList_init: 22929
# sequence length:  80 , signal length:  406 , prob:  0.440387691060702
# sigLenList_init: 22929
# sequence length:  80 , signal length:  409 , prob:  0.4519854750898149
# sigLenList_init: 22929
# sequence length:  80 , signal length:  414 , prob:  0.454581543803215
# sigLenList_init: 22929
# sequence length:  80 , signal length:  414 , prob:  0.4449904773916517
# sigLenList_init: 22929
# sequence length:  80 , signal length:  406 , prob:  0.4979991763830185
# sigLenList_init: 22929
# sequence length:  80 , signal length:  409 , prob:  0.46701230936580235
# sigLenList_init: 22929
# sequence length:  80 , signal length:  408 , prob:  0.4419451542198658
# sigLenList_init: 22929
# sequence length:  80 , signal length:  422 , prob:  0.43268304656852374
# sigLenList_init: 22929
# sequence length:  80 , signal length:  414 , prob:  0.43117750755378176
# sigLenList_init: 22929
# sequence length:  80 , signal length:  414 , prob:  0.4284762761422566
# sigLenList_init: 22929
# sequence length:  80 , signal length:  417 , prob:  0.42094145627582774
# sigLenList_init: 22929
# sequence length:  80 , signal length:  413 , prob:  0.3976835310459137
# sigLenList_init: 22929
# sequence length:  80 , signal length:  409 , prob:  0.37070322699016994
# sigLenList_init: 22929
# sequence length:  80 , signal length:  417 , prob:  0.3982570451848647
# sigLenList_init: 22929
# sequence length:  80 , signal length:  407 , prob:  0.4016190469264984
# sigLenList_init: 22929
# sequence length:  80 , signal length:  409 , prob:  0.3846350908279419
# sigLenList_init: 22929
# sequence length:  80 , signal length:  403 , prob:  0.40465957919756573
# sigLenList_init: 22929
# sequence length:  80 , signal length:  405 , prob:  0.4026539921760559
# sigLenList_init: 22929
# sequence length:  80 , signal length:  404 , prob:  0.42075198888778687
# sigLenList_init: 22929
# sequence length:  80 , signal length:  406 , prob:  0.39324680467446643
# sigLenList_init: 22929

# %%
pStart+1171
# Out:
# 430171

# %%
thisread[read][1][22945:22945+5]
# Out:
# ['225876', '225876', '225880', '225883', '225888']
